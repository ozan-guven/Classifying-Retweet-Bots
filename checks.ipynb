# %%
import json
import csv
import numpy as np
import pandas as pd
import ast

# %%
user_id = {}
with open("new_outputs/users.jsonl", 'r', encoding="UTF-8") as f:
    for line in f:
        dict = ast.literal_eval(line)
        user_id[int(dict["id"])] = dict["created_at"]

# %%
import collections
collections.OrderedDict(sorted(user_id.items())[8000:])
# => The ID are given by date
# Out:
# OrderedDict([(1461382569694568454, '2021-11-18T17:15:38.000Z'),
#              (1461404064160399365, '2021-11-18T18:44:01.000Z'),
#              (1461578143681052674, '2021-11-19T06:12:58.000Z'),
#              (1461712675956797449, '2021-11-19T15:07:19.000Z'),
#              (1462012477194088452, '2021-11-20T10:58:39.000Z'),
#              (1462022758192357376, '2021-11-20T11:39:47.000Z'),
#              (1462035486386663428, '2021-11-20T12:30:22.000Z'),
#              (1462135407907332097, '2021-11-20T19:08:10.000Z'),
#              (1462274369489670144, '2021-11-21T04:19:28.000Z'),
#              (1462336225524682755, '2021-11-21T08:25:16.000Z'),
#              (1462445869689679878, '2021-11-21T15:41:10.000Z'),
#              (1462448331657994252, '2021-11-21T15:50:47.000Z'),
#              (1462503552048316425, '2021-11-21T19:30:05.000Z'),
#              (1462518896552988672, '2021-11-21T20:31:19.000Z'),
#              (1462548977367359490, '2021-11-21T22:30:41.000Z'),
# ...
